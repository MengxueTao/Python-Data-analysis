# %%
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %%
# uniform均匀
# 准备数据
x=range(60)
y_shanghai=[random.uniform(15,18)for i in x]
y_beijing=[random.uniform(1,3)for i in x]

# 创建画布
figure,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,8),dpi=80)

# 绘制图像
axes[0].plot(x,y_shanghai,label="上海")
axes[1].plot(x,y_beijing,color="blue",linestyle="-.",label="北京")

# 显示图例
axes[0].legend()
axes[1].legend()

# 刻度说明
x_label=["11点{}分".format(i) for i in x]

#axes[0].set_xticks(x[::5],x_label[::5])
axes[0].set_xticklabels(x_label[::5])
axes[0].set_yticks(range(0,40,5))
#axes[1].set_xticks(x[::5],x_label[::5])
axes[1].set_xticklabels(x_label[::5])
axes[1].set_yticks(range(0,40,5))

# 添加网格显示
axes[0].grid(True,linestyle="--",alpha=0.5)
axes[1].grid(True,linestyle="--",alpha=0.5)

# 添加描述信息
axes[0].set_xlabel("时间变化")
axes[0].set_ylabel("温度变化")
axes[0].set_title("shanghai城市变化")
axes[1].set_xlabel("时间变化")
axes[1].set_ylabel("温度变化")
axes[1].set_title("beijing城市变化")

# 显示图
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-1774fa398c76> in <module>
#      20
#      21 #axes[0].set_xticks(x[::5],x_label[::5])
# ---> 22 axes[0].set_xticklabels(x[::5],x_label[::5])
#      23 axes[0].set_yticks(range(0,40,5))
#      24 #axes[1].set_xticks(x[::5],x_label[::5])
#
# E:\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_xticklabels(self, labels, fontdict, minor, **kwargs)
#    3418         """
#    3419         if fontdict is not None:
# -> 3420             kwargs.update(fontdict)
#    3421         ret = self.xaxis.set_ticklabels(labels,
#    3422                                         minor=minor, **kwargs)
#
# ValueError: dictionary update sequence element #0 has length 5; 2 is required
